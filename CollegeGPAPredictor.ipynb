# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("C:\\Users\\mruta\\Downloads\\sat_gpa_v1.csv")

# %% [markdown]
# ### COLLEGE GPA PREDICTOR
#
# # Predicting GPA based on SAT score
# # x = features used to predict outcome
# # y = df['sat_sum']

# %%
print(df.head())
# Out:
#    sat_sum  fy_gpa
# 0     1270    3.18
# 1     1220    3.33
# 2     1160    3.25
# 3      950    2.42
# 4     1070    2.63

# %%
sns.scatterplot(x='sat_sum', y='fy_gpa', data=df)
plt.title('Scatter Plot of SAT Scores vs. GPA')
plt.xlabel('SAT Scores')
plt.ylabel('GPA')
plt.show()

# %%
X = df[['sat_sum']]
y = df['fy_gpa']

model = LinearRegression()

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X, y, label='Data')
plt.plot(X, y_pred, color='red', linewidth=2, label='Linear Regression')
plt.title('Scatter Plot of SAT Scores vs. GPA')
plt.xlabel('SAT Scores')
plt.ylabel('GPA')
plt.legend()
plt.show()

plt.rcParams["figure.figsize"] = [12, 6]

# %%
print(f'Slope (Coefficient): {model.coef_[0]}')
print(f'Intercept: {model.intercept_}')
# Out:
# Slope (Coefficient): 0.002386573594038179
# Intercept: 0.001927371016289925

# %%
plt.rcParams["figure.figsize"] = [12, 6]
